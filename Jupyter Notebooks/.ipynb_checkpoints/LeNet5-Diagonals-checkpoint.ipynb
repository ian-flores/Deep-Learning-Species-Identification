# %%
# %matplotlib inline
import numpy as np
import itertools
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range
import random
import matplotlib.pyplot as plt
from tensorflow.contrib.layers import flatten
from PIL import Image, ImageOps
from scipy.ndimage.interpolation import shift 
from IPython.display import Image as Im 
from sklearn.utils import shuffle
import sklearn
import pandas

# Our "library"
from data_augmentation import *

# %%
pickle_file = '../dataset/arbimon_0.pickle'

# %%
def execute(aug_shifts, pickle_file):
    print("=====================")
    print("Aug Shifts: " + str(aug_shifts + 1))
    
    with open(pickle_file, 'rb') as f:
        save = pickle.load(f)
        train_dataset = save['train_dataset']
        train_labels = save['train_labels']
        test_dataset = save['test_dataset']
        test_labels = save['test_labels']
        del save

    print('Original Training Set Shape: ', train_dataset.shape, train_labels.shape)
    print('Original Test Set Shape: ', test_dataset.shape, test_labels.shape)
    
    augmented_train_dataset, augmented_train_labels = diagonal_augmentation(train_dataset, aug_shifts, train_labels)
    #augmented_test_dataset, augmented_test_labels = diagonal_augmentation(test_dataset, aug_shifts, test_labels)
    
    print()
    print('Augmented Training Set Shape: ', augmented_train_dataset.shape, augmented_train_labels.shape)
    #print('Augmented Test Set Shape: ', augmented_test_dataset.shape, augmented_test_labels.shape)
    
    augmented_train_dataset = reformat(augmented_train_dataset)
    #augmented_test_dataset = reformat(augmented_test_dataset)
    test_dataset = reformat(test_dataset)
    
    X_train = np.pad(augmented_train_dataset, ((0,0),(2,2),(2,2),(0,0)), 'constant')
    #X_test = np.pad(augmented_test_dataset, ((0,0),(2,2),(2,2),(0,0)), 'constant')
    test_dataset = np.pad(test_dataset, ((0,0), (2,2), (2,2), (0,0)), 'constant')

    y_train = augmented_train_labels
    #y_test = augmented_test_labels
    
    X_train, y_train = shuffle(X_train, y_train)
    
    EPOCHS = 50
    BATCH_SIZE = 5
    rate = 0.05

    x = tf.placeholder(tf.float32, (None, 32, 32, 1))
    y = tf.placeholder(tf.int32, (None))
    one_hot_y = tf.one_hot(y, 21)

    logits = LeNet(x)
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits = logits, labels = one_hot_y)
    loss_operation = tf.reduce_mean(cross_entropy)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate = rate)
    training_operation = optimizer.minimize(loss_operation)
    
    correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
    accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    def evaluate(X_data, y_data):
        sess = tf.get_default_session()
        accuracy = sess.run(accuracy_operation, feed_dict={x: X_data, y: y_data})
        return accuracy
    
    #augmented_rendimiento = []
    #augmented_confusion_matrices = []
    
    non_augmented_rendimiento = []
    non_augmented_confusion_matrices = []
    
    for i in range(5):
        print()
        print("Sample #",  str(i+1))
        #augmented_prediction_labels = []
        non_augmented_prediction_labels = []

        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            num_examples = len(X_train)

            for i in range(EPOCHS):
                X_train, y_train = shuffle(X_train, y_train)
                for offset in range(0, num_examples, BATCH_SIZE):
                    end = offset + BATCH_SIZE
                    batch_x, batch_y = X_train[offset:end], y_train[offset:end]
                    sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})

                train_accuracy = evaluate(X_train, y_train)
                if (i%10 == 0):
                    print("EPOCH {} ".format(i+1))

            probs = tf.nn.softmax(logits)
            
            #augmented_test_accuracy = evaluate(X_test, y_test)
            #augmented_predictions = sess.run(probs, feed_dict={x: X_test, y: y_test})
            #print("Augmented Test Accuracy = {:.3f}".format(augmented_test_accuracy))
            
            non_augmented_test_accuracy = evaluate(test_dataset, test_labels)
            non_augmented_predictions = sess.run(probs, feed_dict={x: test_dataset, y: test_labels})
            print("Non-Augmented Test Accuracy = {:.3f}".format(non_augmented_test_accuracy))

        #for prediction in  augmented_predictions:
         #   augmented_prediction_labels.append(np.argmax(prediction))
            
        #with tf.Session() as sess:
            #augmented_cm = sklearn.metrics.confusion_matrix(y_test, augmented_prediction_labels)
           
        
        for prediction in  non_augmented_predictions:
            non_augmented_prediction_labels.append(np.argmax(prediction))
        
        with tf.Session() as sess:
            non_augmented_cm = sklearn.metrics.confusion_matrix(test_labels, non_augmented_prediction_labels)
            
        #augmented_rendimiento.append(augmented_test_accuracy)
        #augmented_confusion_matrices.append([augmented_cm])
        
        non_augmented_rendimiento.append(non_augmented_test_accuracy)
        non_augmented_confusion_matrices.append([non_augmented_cm])
        
    #augmented_confusion_data.loc[len(augmented_confusion_data)] = augmented_confusion_matrices
    #augmented_performance.loc[len(augmented_performance)] = augmented_rendimiento
    
    non_augmented_confusion_data.loc[len(non_augmented_confusion_data)] = non_augmented_confusion_matrices
    non_augmented_performance.loc[len(non_augmented_performance)] = non_augmented_rendimiento

# %%
#augmented_confusion_data = pandas.DataFrame(columns = list('123'))
#augmented_performance = pandas.DataFrame(columns = list('123'))

non_augmented_confusion_data = pandas.DataFrame(columns = list('12345'))
non_augmented_performance = pandas.DataFrame(columns = list('12345'))

for i in range(22):
    execute(aug_shifts = i, pickle_file = pickle_file)

#augmented_performance.to_pickle('results/diagonal_augmented_test/performance_diagonal_augmented_test.pkl')
#augmented_confusion_data.to_pickle('results/diagonal_augmented_test/confusion_matrices_diagonal_augmented_test.pkl')

non_augmented_confusion_data.to_pickle('results/diagonal_non_augmented_test/confusion_matrices_diagonal_non_augmented_test.pkl')
non_augmented_performance.to_pickle('results/diagonal_non_augmented_test/performance_diagonal_non_augmented_test.pkl')
# Out:
# =====================
# Aug Shifts: 1
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (660, 28, 28) (660,)
# WARNING:tensorflow:From <ipython-input-3-c81b0db5d5de>:45: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.780
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.780
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.817
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.805
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.829
# =====================
# Aug Shifts: 2
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (1320, 28, 28) (1320,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.878
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.829
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.854
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.878
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.805
# =====================
# Aug Shifts: 3
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (1980, 28, 28) (1980,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.866
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.854
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.841
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.866
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.841
# =====================
# Aug Shifts: 4
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (2640, 28, 28) (2640,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.866
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.927
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.927
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.902
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.951
# =====================
# Aug Shifts: 5
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (3300, 28, 28) (3300,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.927
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.939
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.927
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.963
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.878
# =====================
# Aug Shifts: 6
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (3960, 28, 28) (3960,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.951
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.939
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.939
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.939
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.939
# =====================
# Aug Shifts: 7
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (4620, 28, 28) (4620,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.915
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.939
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.915
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.915
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.915
# =====================
# Aug Shifts: 8
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (5280, 28, 28) (5280,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.951
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.927
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.927
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.939
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.915
# =====================
# Aug Shifts: 9
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (5940, 28, 28) (5940,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.939
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.902
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.927
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.805
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.902
# =====================
# Aug Shifts: 10
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (6600, 28, 28) (6600,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.927
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.915
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.915
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.878
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.866
# =====================
# Aug Shifts: 11
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (7260, 28, 28) (7260,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.927
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.902
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.805
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.793
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.927
# =====================
# Aug Shifts: 12
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (7920, 28, 28) (7920,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.890
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.854
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.646
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.915
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.854
# =====================
# Aug Shifts: 13
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (8580, 28, 28) (8580,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.890
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.829
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.829
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.695
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.854
# =====================
# Aug Shifts: 14
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (9240, 28, 28) (9240,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.939
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.927
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.817
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.878
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.890
# =====================
# Aug Shifts: 15
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (9900, 28, 28) (9900,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.854
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.683
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.793
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.817
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.890
# =====================
# Aug Shifts: 16
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (10560, 28, 28) (10560,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.793
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.890
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.866
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.854
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.707
# =====================
# Aug Shifts: 17
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (11220, 28, 28) (11220,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.829
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.841
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.890
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.512
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.854
# =====================
# Aug Shifts: 18
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (11880, 28, 28) (11880,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.171
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.171
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.841
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.829
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.171
# =====================
# Aug Shifts: 19
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (12540, 28, 28) (12540,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.707
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.793
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.866
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.171
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.171
# =====================
# Aug Shifts: 20
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (13200, 28, 28) (13200,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.171
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.829
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.866
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.585
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.207
# =====================
# Aug Shifts: 21
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (13860, 28, 28) (13860,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.878
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.171
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.171
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.171
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.768
# =====================
# Aug Shifts: 22
# Original Training Set Shape:  (165, 28, 28) (165,)
# Original Test Set Shape:  (82, 28, 28) (82,)
#
# Augmented Training Set Shape:  (14520, 28, 28) (14520,)
#
# Sample # 1
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.171
#
# Sample # 2
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.890
#
# Sample # 3
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.171
#
# Sample # 4
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.171
#
# Sample # 5
# EPOCH 1
# EPOCH 11
# EPOCH 21
# EPOCH 31
# EPOCH 41
# Non-Augmented Test Accuracy = 0.817

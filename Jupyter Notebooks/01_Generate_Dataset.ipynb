# %% [markdown]
# # Generate Dataset

# %% [markdown]
# By Alejandro Vega & Ian Flores

# %% [markdown]
# ### Loading the necessary dependencies
# The installation of this dependencies and the Python version (3.6) here used is better suited if doing with Anaconda.

# %%
import pylab
import wave
import openpyxl
import yaml
import os
import shutil
import _pickle as cpl
import tarfile
import pandas as pd
import getpass

# %% [markdown]
# ### Audio Preprocessing

# %%
# import subprocess

# user = subprocess.run(["whoami"], stdout=subprocess.PIPE)
# ohoh = subprocess.run(["ls ../"], stdout=subprocess.PIPE)
# user2 = subprocess.run(["ls -l"], stdout=subprocess.PIPE)
# print(user, sys, user2)

# %% [markdown]
# Given that we have .flac files in our dataset, we need to convert this to .wav format before doing the transformations to spectrograms. To be able to do this, we call bash script, specifically the 'sox' package to help us. For this, you have to have 'sox' installed in your computer. In Ubuntu 17.10, the command is pretty straightforward. 'sudo apt install sox'. After the transformation we store all the files in format .wav in a directory called 'wav_recordings'.

# %%
# Get all the recordings and separate them by format. 
flac_files = []
wav_files = []
#print(os.listdir("../dataset/recordings"))
for file in os.listdir("../dataset/recordings"):
    if file.endswith(".flac"):
        print('flac')
        flac_files.append(file)
    elif file.endswith(".wav"):
        wav_files.append(file)

# %%
flac_files
# Out:
# []

# %%
# Convert all the .flac files to .wav files and store them in 'wav_recordings'
for i in range(len(flac_files)):
    string = 'sox ../recordings/' + str(flac_files[i]) + ' ../wav_recordings/' + str(flac_files[i][:-5]) + '.wav'
    os.system(string)

# %%
# Store the .wav files in 'wav_recordings'
for i in range(len(wav_files)):
    ### !!!! extremely unsafe
    string = 'mv ../' + str(wav_files[i]) + ' ../wav_recordings'
    os.system(string)

# %% [markdown]
# ### Transformations and Spectrogram Informations

# %% [markdown]
# In this section, we first get the information from the wav files, then the information regarding the spectrogram, and it's Region of Interest, which is where the animal call is focused. Then, after all this information is collected we proceed to plot the spectrogram for the full recording.

# %%
# Get the Info from the .wav file.
def wavInfo(rec_file):
    wav_file = wave.open(rec_file, 'r')
    frames = wav_file.readframes(-1)
    wave_info = pylab.fromstring(frames, 'Int16') #all .wavs in our dataset are 16bit
    framerate = wav_file.getframerate()
    wav_file.close()
    return wave_info, framerate

# Get the info from the Spectrogram, but don't plot it.
def specInfo(rec_file):
    wave_info, framerate = wavInfo(rec_file)
    spectrum, freqs, t, _ = pylab.specgram(wave_info, NFFT=512, noverlap=256, window=pylab.window_hanning, Fs=framerate)
    del _
    return spectrum, freqs, t

# %%
# search for the index of the leftmost value in an ordered array 
# (of times or frequencies in our case) that still meet our criteria
def leftmostBinSearch(A, lo, hi, target):
    mid = (lo + hi) // 2
    v1 = A[mid]
    if (v1 >= target):
        if (mid > 0 and A[mid - 1] > target):
            return leftmostBinSearch(A, lo, mid-1, target)
        else:
            return mid
    elif (A[mid] < target):
        return leftmostBinSearch(A, mid+1, hi, target)
    else:
        return leftmostBinSearch(A, lo, mid-1, target)

# search for the index of the rightmost value in an ordered array 
# (of times or frequencies in our case) that still meet our criteria
def rightmostBinSearch(A, lo, hi, target): # something is wrong and it's giving me 1 to the right 
    mid = (lo + hi) // 2
    v1 = A[mid]
    if (v1 <= target):
        if (mid < (len(A) - 1) and A[mid + 1] <= target):
            return rightmostBinSearch(A, mid+1, hi, target)
        else:
            return mid
    elif (A[mid] < target):
        return rightmostBinSearch(A, mid+1, hi, target)
    else:
        return rightmostBinSearch(A, lo, mid-1, target)
    
# Calls on rightmostBinSearch and leftmostBinSearch
def getBounds(A, minVal, maxVal):
    left = leftmostBinSearch(A, 0, len(A)-1, minVal)
    right = rightmostBinSearch(A, 0, len(A)-1, maxVal)
    return left, right

# %%
def specMod(spectrum, freqs, times, f1, f2, t1, t2):
    spectrumMod = [spectrum[f1][t1:t2]]
    for f in range(f1+1, f2): # check when fix right limit
            spectrumMod = spectrumMod + [spectrum[f][t1:t2]]
    return spectrumMod

# Plots the spectrogram
def plotModSpecSimple(specMod, freqs, times, file):
    fig, ax = pylab.subplots(1)
    pylab.pcolormesh(times, freqs, 10 * pylab.log10(specMod))
    fig.subplots_adjust(left=0,right=1,bottom=0,top=1)
    ax.axis('tight')
    ax.axis('off')
    pylab.savefig(file)
    return fig

# %%
# Creates the speciesData dictionary which is a dict with all the information we have regarding the different species. 
def speciesData(workbook):
    roi_ws = openpyxl.load_workbook(workbook)['ROIs']
    dataset = {}
    # needed format:
    # species specimen per row
    # columns: species name, start_time, end_time, min_freq, max_freq, recording name
    # columns A to F
    sheetMatrix = list(roi_ws.iter_rows())
    # remove row with column names and create array of keys per species. (e.g. start_time, end_time, ...)
    keys = sheetMatrix.pop(0) 
    for row in sheetMatrix:
        speciesName = row[0].value
        if (speciesName not in dataset):
            dataset[speciesName] = {}
        for col in range(1,len(row)):
            cell = ''
            # change recording extension since we are dealing with wav files
            if (col == 5):
                cell = row[col].value
                cell += '.wav'
            else:
                cell = row[col].value
            # if per species key is not present add the key and add the value as the first element in a list
            if (keys[col].value not in dataset[speciesName]): 
                dataset[speciesName][keys[col].value] = [cell]
            # append to the list of attributes 
            else:
                dataset[speciesName][keys[col].value] = dataset[speciesName][keys[col].value] + [cell]
    return dataset

# Convert speciesData dictionary to yaml and save file
def dataToYAML(data, name): 
    # need to check if file exists then delete it
    path = '../dataset/' + name
    dataset = open(path, 'w+')
    dump = yaml.dump(data, dataset, default_flow_style=False)
    dataset.close()

# As it names suggests, it find the maximum. 
def findMax(L):
    Max = float('-inf')
    for n in L:
        if (n > Max):
            Max = n
    return Max

# As it names suggests, it find the minimum. 
def findMin(L):
    Min = float('inf')
    for n in L:
        if (n < Min):
            Min = n
    return Min

# %%
def simplifiedSpeciesData(data): 
    simplDat = {}
    for species in data:
        min_freqs = data[species]['min_frequency']
        max_freqs = data[species]['max_frequency']
        min_times = data[species]['start_time']
        max_times = data[species]['end_time']
        min_f = findMin(min_freqs)
        max_f = findMax(max_freqs)
        start = findMin(min_times)
        end = findMax(max_times)
        simplDat[species] = {'min_freq':min_f, 'max_freq':max_f, 'delta_time':(end - start), 'recording name':data[species]['recording name']}
    return simplDat

# %% [markdown]
# ### Validating Data

# %% [markdown]
# Given that this data was manually labeled, and this is very time intensive, we have less validations than recordings, so we have to make sure to only be managing the recordings for which we have validations.

# %%
os.getcwd()
# Out:
# '/home/jovyan/work/ianWork/Jupyter Notebooks'

# %%
# Loads the validation data
df = pd.ExcelFile('../dataset/validationsAndROIs.xlsx')
df = df.parse('ROIs')
rs =[]


# Gets the name of all the rcordings
all_wav_files = []
for file in os.listdir("../dataset/recordings"):
    all_wav_files.append(file[:file.index('.')])

# Extracts the recording_name column and stores it as a list
recording_name = df["recording name"].tolist()

# Formats the string containing the name of the recording to remove everything after the first dot.
for i in range(len(recording_name)):
    recording_name[i] = recording_name[i][:recording_name[i].index('.')]

# If we don't have a recording, then the validation data is not useful by itself. So we want to remove this data. 
for i in range(len(recording_name)):
    if recording_name[i] not in all_wav_files:
        rs.append(recording_name[i])
        recording_name[i] = "delete"

# Creates the column 'recording name' initialized with the corresponding values in tecording_name list, 
# then removes the data labeled as delete

df['recording name'] = recording_name
df = df[df['recording name'] != 'delete']

# Writes out the corrected validation data. 
writer = pd.ExcelWriter('../dataset/corrected_validationsAndROIs.xlsx')
df.to_excel(writer, 'ROIs', index=False)
writer.save()

# Standarizes the names of all the recording names
# changed recordings dir since they're already converted to wav
for files in os.listdir("../dataset/recordings"):
    new_name = files[:files.index('.')]
    os.rename("../dataset/recordings/" + files, "../dataset/recordings/" + new_name + '.wav')
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/io/excel.py:784: DeprecationWarning: Call to deprecated function remove_sheet (Use wb.remove(worksheet) or del wb[sheetname]).
#   self.book.remove_sheet(self.book.worksheets[0])

# %%
#df
pd.set_option('display.max_rows', 500)
print(df)
#df.loc[df['recording name'] == 'delete']
# Out:
#             Species Scientific name  start_time   end_time  min_frequency  \
# 0           Basileuterus bivittatus   40.789522  43.125341    1805.818966
# 1           Basileuterus bivittatus   12.808322  14.621586    2318.750000
# 2           Basileuterus bivittatus   15.825704  18.053577    1900.000000
# 3           Basileuterus bivittatus    3.030180   4.970630    2568.750000
# 4           Basileuterus bivittatus   13.690107  15.484645    2250.000000
# 5           Basileuterus bivittatus   18.126360  20.473414    1687.500000
# 6           Basileuterus bivittatus   52.576568  54.735051    1687.500000
# 7           Basileuterus bivittatus    7.383310   9.674682    2379.496403
# 8           Basileuterus bivittatus   32.198255  34.193973    2296.540422
# 9           Basileuterus bivittatus   49.033427  50.950107    2521.376548
# 10          Basileuterus bivittatus   22.565454  24.383336    2810.451566
# 11          Basileuterus bivittatus   25.025523  26.981722    2356.793478
# 12          Basileuterus bivittatus    5.927877   7.785279    2633.794610
# 13          Basileuterus bivittatus    5.134371   7.298444    2585.615441
# 14          Basileuterus bivittatus   15.021216  16.845827    2553.495994
# 15        Basileuterus chrysogaster   54.610142  56.390737    2841.576674
# 16        Basileuterus chrysogaster   16.086165  18.669701    2595.795602
# 17        Basileuterus chrysogaster   16.838113  18.452240    2808.917197
# 18        Basileuterus chrysogaster   36.949434  38.850526    2738.421734
# 19        Basileuterus chrysogaster    4.484628   6.970672    2538.745149
# 20          Chlorothraupis carmioli   39.646158  44.631635    1225.000000
# 21          Chlorothraupis carmioli   35.051409  39.970624    1250.000000
# 22          Chlorothraupis carmioli   16.752487  21.878291    1343.750000
# 23          Chlorothraupis carmioli    8.512710  11.671174    1325.000000
# 24          Chlorothraupis carmioli   19.350041  24.736987    1271.090784
# 25          Chlorothraupis carmioli   51.550540  56.624141    1463.865706
# 26          Chlorothraupis carmioli    3.971880   7.545401    1255.728814
# 27          Chlorothraupis carmioli   20.410959  26.331811    1258.436725
# 28          Chlorothraupis carmioli   28.795834  33.443263    1451.729929
# 29          Chlorothraupis carmioli   54.309979  58.036093    1320.739910
# 30          Chlorothraupis carmioli   16.161068  19.916545    1537.821888
# 31       Eleutherodactylus brittoni   50.036808  50.310875    4627.777778
# 32       Eleutherodactylus brittoni   48.368876  48.675245    5175.000000
# 33       Eleutherodactylus brittoni   57.823800  58.044018    4806.250000
# 34       Eleutherodactylus brittoni   48.797701  49.103096    4868.750000
# 35       Eleutherodactylus brittoni    8.518451   8.781331    4606.837607
# 36       Eleutherodactylus brittoni    1.296250   1.511250    4943.750000
# 37       Eleutherodactylus brittoni    5.117491   5.350940    5087.500000
# 38       Eleutherodactylus brittoni    5.290816   5.554519    4968.771930
# 39       Eleutherodactylus brittoni   55.453323  55.756516    4256.250000
# 40       Eleutherodactylus brittoni    8.209512   8.647353    4498.061864
# 41       Eleutherodactylus brittoni   12.132097  12.478728    4428.993735
# 42       Eleutherodactylus brittoni   52.806663  53.170039    5100.967742
# 43       Eleutherodactylus brittoni    3.503706   3.958844    4400.565403
# 44       Eleutherodactylus brittoni   53.202562  53.504595    4439.316239
# 45      Eleutherodactylus cochranae   27.462635  27.820600    3785.692771
# 46      Eleutherodactylus cochranae   24.434228  24.879206    3873.931624
# 47      Eleutherodactylus cochranae    0.504308   0.889956    4041.452991
# 48      Eleutherodactylus cochranae   38.475751  38.851510    4020.512821
# 49      Eleutherodactylus cochranae   15.416010  15.831323    3790.170940
# 50      Eleutherodactylus cochranae   16.266412  16.642171    4020.512821
# 51      Eleutherodactylus cochranae   39.078943  39.484367    3748.290598
# 52      Eleutherodactylus cochranae   17.938009  18.334334    3743.691589
# 53      Eleutherodactylus cochranae   37.133920  37.504397    3709.345794
# 54      Eleutherodactylus cochranae   10.356142  10.769698    3675.000000
# 55      Eleutherodactylus cochranae   26.614078  27.001788    3863.901869
# 56      Eleutherodactylus cochranae   17.748463  18.118940    3760.864486
# 57      Eleutherodactylus cochranae   19.936865  20.290112    3898.247664
# 58      Eleutherodactylus cochranae   23.415723  23.821147    3818.900602
# 59      Eleutherodactylus cochranae   29.091663  29.477310    3984.939759
# 60      Eleutherodactylus cochranae   57.451707  57.760519    3650.000000
# 61      Eleutherodactylus cochranae   12.256076  12.635689    4287.500000
# 62      Eleutherodactylus cochranae   15.740380  16.133551    3875.000000
# 63      Eleutherodactylus cochranae    7.898960   8.416478    3825.000000
# 64      Eleutherodactylus cochranae    8.648000   9.124661    4200.000000
# 65      Eleutherodactylus cochranae   18.753221  19.175407    4050.000000
# 66      Eleutherodactylus cochranae   13.945750  14.395174    3887.500000
# 67      Eleutherodactylus cochranae   53.914032  54.380484    4031.250000
# 68      Eleutherodactylus cochranae   32.395065  32.830419    4012.500000
# 69      Eleutherodactylus cochranae    6.414873   6.646736    4252.307457
# 70          Eleutherodactylus cooki    1.422691   2.499588    1330.359435
# 71          Eleutherodactylus cooki    1.956200   3.072616    1359.819734
# 72          Eleutherodactylus cooki   33.571546  34.529886    1506.261860
# 73          Eleutherodactylus cooki    6.580321   7.469251    1353.767442
# 74          Eleutherodactylus cooki   37.061126  38.140142    1394.790698
# 75          Eleutherodactylus cooki    2.587177   3.445499    1488.036810
# 76          Eleutherodactylus cooki   13.563176  14.631010    1239.653110
# 77          Eleutherodactylus cooki   58.166232  59.127842    1345.155502
# 78          Eleutherodactylus cooki    3.673127   4.562057    1292.404306
# 79          Eleutherodactylus cooki    2.046217   3.041372    1397.906699
# 80          Eleutherodactylus cooki   12.036899  13.020872    1397.906699
# 81          Eleutherodactylus cooki   38.061871  39.213567    1345.155502
# 82          Eleutherodactylus cooki   21.765190  22.792689    1359.819734
# 83          Eleutherodactylus cooki    2.800566   4.413013    1386.970475
# 84          Eleutherodactylus cooki    9.632249  10.905233    1401.660342
# 85          Eleutherodactylus cooki   50.834512  52.234795    1380.740038
# 86          Eleutherodactylus coqui    2.416264   2.774229    1633.333333
# 87          Eleutherodactylus coqui   26.712783  27.067654    1738.034188
# 88          Eleutherodactylus coqui   14.690081  15.009854    1717.094017
# 89          Eleutherodactylus coqui   19.673867  20.009239    1779.914530
# 90          Eleutherodactylus coqui    7.635452   8.179116    1538.842975
# 91          Eleutherodactylus coqui   13.249527  13.687377    1545.399374
# 92          Eleutherodactylus coqui   24.806945  25.249357    1528.132341
# 93          Eleutherodactylus coqui    3.167579   3.695509    1603.099911
# 94          Eleutherodactylus coqui    8.203776   8.660530    1534.255129
# 95          Eleutherodactylus coqui   20.504688  20.935365    1332.069409
# 96          Eleutherodactylus coqui   43.727674  44.091232    1785.539846
# 97          Eleutherodactylus coqui   30.315169  30.673134    1738.034188
# 98          Eleutherodactylus coqui   36.104136  36.439728    1758.974359
# 99   Eleutherodactylus juanariveroi    3.836698   4.439890    7329.059829
# 100  Eleutherodactylus juanariveroi   59.004965  59.678076    6681.250000
# 101  Eleutherodactylus juanariveroi    1.720088   2.486309    6690.974941
# 102  Eleutherodactylus juanariveroi   10.946016  11.884246    6673.707909
# 103  Eleutherodactylus juanariveroi    1.913746   3.057594    6904.148082
# 104            Epinephelus guttatus   13.283183  14.127913      50.651230
# 105            Epinephelus guttatus    4.518142   5.533368      50.651230
# 106            Epinephelus guttatus   16.762850  17.568830      43.415340
# 107            Epinephelus guttatus    7.889312   8.819289      43.415340
# 108            Epinephelus guttatus    1.410466   2.224197      43.415340
# 109            Epinephelus guttatus    7.168579   8.145056      50.651230
# 110            Epinephelus guttatus    3.564915   4.580141      57.887120
# 111            Epinephelus guttatus    5.889859   7.029082      50.651230
# 112            Epinephelus guttatus    6.409097   7.346825      43.415340
# 113            Epinephelus guttatus    7.145329   8.044308      57.887120
# 114            Epinephelus guttatus    1.263220   2.022702      43.415340
# 115            Epinephelus guttatus    5.231125   6.285100      36.179450
# 116            Epinephelus guttatus    2.014952   2.937180      50.651230
# 117            Epinephelus guttatus    4.936632   5.796862      50.651230
# 118            Epinephelus guttatus    2.882931   3.750910      50.651230
# 119            Epinephelus guttatus   16.228113  17.227839      43.415340
# 120            Epinephelus guttatus    7.618068   8.532546      50.651230
# 121              Formicarius analis   54.660169  56.499169    1682.416880
# 122              Formicarius analis   42.950142  44.875518    1687.500000
# 123              Formicarius analis   26.438876  28.476844    1675.000000
# 124              Formicarius analis   22.443505  24.557298    1643.754197
# 125              Formicarius analis   12.637970  14.823145    1693.750000
# 126              Formicarius analis    9.909149  11.890979    1706.250000
# 127              Formicarius analis   14.873832  16.990654    1675.000000
# 128              Formicarius analis   33.659680  35.635985    1712.500000
# 129              Formicarius analis   33.053008  35.341087    1693.750000
# 130              Formicarius analis   28.926890  31.139002    1700.000000
# 131              Formicarius analis   26.545388  28.597417    1614.341085
# 132             Hypocnemis subflava   19.601515  22.190021    2256.929348
# 133             Hypocnemis subflava   17.339042  19.334760    2236.956522
# 134             Hypocnemis subflava   31.694385  34.253252    2296.875000
# 135             Hypocnemis subflava   40.803920  43.070805    2175.000000
# 136             Hypocnemis subflava   29.459941  31.268189    2143.750000
# 137             Hypocnemis subflava   42.267695  45.729621    2100.901288
# 138             Hypocnemis subflava   20.070721  22.362093    2326.618705
# 139             Hypocnemis subflava   33.479491  36.152758    2326.618705
# 140             Hypocnemis subflava   18.098131  19.906542    2287.500000
# 141             Hypocnemis subflava    5.628155   7.378015    2306.250000
# 142             Hypocnemis subflava    4.877331   6.918548    2156.250000
# 143             Hypocnemis subflava   18.662934  21.251441    2200.182083
# 144             Hypocnemis subflava   30.212416  32.326692    2152.002913
# 145             Hypocnemis subflava   39.074592  41.712498    2103.823744
# 146             Hypocnemis subflava   32.423619  34.829612    2337.500000
# 147             Hypocnemis subflava    9.941520  12.485380    2260.369276
# 148             Hypocnemis subflava   27.650491  30.608108    2368.750000
# 149             Hypocnemis subflava   24.405653  25.943475    2093.750000
# 150             Hypocnemis subflava   25.600721  26.790446    2050.000000
# 151             Hypocnemis subflava   11.155176  13.665636    2300.043103
# 152             Hypocnemis subflava   22.397671  25.683100    2490.129310
# 153             Hypocnemis subflava   20.214663  22.517737    2194.791667
# 154             Hypocnemis subflava   34.709842  37.089321    2220.312500
# 155             Hypocnemis subflava   39.568672  40.981839    2377.428910
# 156                  Unknown Insect   22.242221  26.503182    9551.221080
# 157                  Unknown Insect   18.705622  22.881365    9551.221080
# 158                  Unknown Insect   10.396747  13.592468    9551.221080
# 159                  Unknown Insect   14.998586  18.705622    9466.195373
# 160                  Unknown Insect   18.876061  23.264851    9324.485861
# 161                  Unknown Insect   31.318069  35.919908   10061.375321
# 162                  Unknown Insect   17.640382  22.710926    9607.904884
# 163                  Unknown Insect   12.058522  16.916018    8814.331620
# 164                  Unknown Insect    4.985325   9.118458    9976.349614
# 165                  Unknown Insect   42.654241  46.491708   10576.237624
# 166            Liosceles thoracicus   32.945810  38.649767    1168.750000
# 167            Liosceles thoracicus    5.385039  10.087192    1071.042799
# 168            Liosceles thoracicus   41.510725  47.261744    1130.193483
# 169            Liosceles thoracicus   51.993000  55.601419    1125.000000
# 170            Liosceles thoracicus   48.980949  53.818971    1112.500000
# 171            Liosceles thoracicus   17.511525  22.240334    1168.750000
# 172            Liosceles thoracicus   28.896030  33.639245    1176.888218
# 173            Liosceles thoracicus   16.937252  21.341129    1170.448878
# 174            Liosceles thoracicus   36.693122  42.483672    1093.750000
# 175            Liosceles thoracicus   39.868297  46.566322    1050.000000
# 176            Liosceles thoracicus   39.868297  46.566322    1050.000000
# 177            Liosceles thoracicus   13.740886  18.710039    1093.750000
# 178            Liosceles thoracicus   42.762557  47.716895    1100.000000
# 179            Liosceles thoracicus    9.708877  14.788355    1156.250000
# 180            Megascops guatemalae   29.953075  36.065948     666.795138
# 181            Megascops guatemalae   29.953075  36.065948     666.795138
# 182            Megascops guatemalae   41.884365  48.830739     659.897392
# 183            Megascops guatemalae   32.702361  38.258750     692.284569
# 184            Megascops guatemalae   47.363194  53.890278     692.284569
# 185            Megascops guatemalae   17.336407  24.021354     674.290668
# 186               Megascops nudipes   38.092858  40.538627     293.750000
# 187               Megascops nudipes   19.734302  22.745655     312.500000
# 188               Megascops nudipes   11.237976  14.080846     343.750000
# 189               Megascops nudipes   26.300476  29.127639     381.250000
# 190               Megascops nudipes   39.424053  41.313350     348.556701
# 191               Megascops nudipes   24.319521  27.095821     331.250000
# 192               Megascops nudipes   28.286427  30.984188     337.500000
# 193               Megascops nudipes   11.433321  14.089092     312.500000
# 194               Megascops nudipes   13.997475  16.359151     323.455056
# 195               Megascops nudipes   45.062604  47.387947     323.455056
# 196               Megascops nudipes   16.701728  19.344566     306.250000
# 197               Megascops nudipes   42.335577  44.668969     350.000000
# 198               Megascops nudipes   34.564518  37.249471     318.750000
# 199               Megascops nudipes   12.012869  13.421651     330.900409
# 200               Megascops nudipes   13.369623  16.600235     381.250000
# 201        Microcerculus marginatus    8.805630  10.998016    2754.137931
# 202        Microcerculus marginatus   28.306190  30.308409    2732.595263
# 203        Microcerculus marginatus   30.556310  32.663948    2743.750000
# 204        Microcerculus marginatus   12.317288  14.425280    2687.500000
# 205        Microcerculus marginatus   43.224477  45.333623    2850.000000
# 206        Microcerculus marginatus   25.269834  27.302024    2888.689937
# 207        Microcerculus marginatus   20.271055  22.623427    2725.000000
# 208        Microcerculus marginatus   15.758653  17.456891    2862.660863
# 209        Microcerculus marginatus   20.166611  21.895464    2918.899522
# 210        Microcerculus marginatus   19.077544  21.046694    2849.538462
# 211        Microcerculus marginatus   45.130140  46.601283    2818.750000
# 212        Microcerculus marginatus   12.270776  14.182749    2758.672722
# 213           Myrmoborus leucophrys   28.571588  33.463183    1948.904310
# 214           Myrmoborus leucophrys   11.014570  16.049159    1881.250000
# 215           Myrmoborus leucophrys    8.901696  12.952412    2007.465404
# 216           Myrmoborus leucophrys   16.284775  19.811610    2218.750000
# 217           Myrmoborus leucophrys   49.572193  54.224599    1456.250000
# 218           Myrmoborus leucophrys   21.262507  25.999636    2181.250000
# 219           Myrmoborus leucophrys   14.954270  20.124564    1761.783920
# 220           Myrmoborus leucophrys   23.046109  28.053411    1887.500000
# 221           Myrmoborus leucophrys   18.116269  23.402434    1893.750000
# 222           Myrmoborus leucophrys    5.365107  11.110625    1829.613734
# 223           Myrmoborus leucophrys   28.611889  33.818541    1639.208633
# 224           Myrmoborus leucophrys   32.451759  37.287174    1933.293839
# 225           Myrmoborus leucophrys   34.035897  37.809979    2425.018208
# 226           Myrmoborus leucophrys   32.939239  36.970196    2232.301530
# 227           Myrmoborus leucophrys   51.552775  55.386135    2216.241806
# 228           Myrmoborus leucophrys   29.945661  33.650585    2360.779315
# 229           Myrmoborus leucophrys   43.925572  47.847851    2376.839039
# 230           Myrmoborus leucophrys   46.930693  50.919378    2296.540422
# 231           Myrmoborus leucophrys   52.125803  56.482793    1477.494538
# 232           Myrmoborus leucophrys   23.019924  26.882924    2103.823744
# 233           Myrmoborus leucophrys   23.019924  26.882924    2103.823744
# 234           Myrmoborus leucophrys    0.484110   4.327351    2232.301530
# 235           Myrmeciza hemimelaena   15.934539  17.493640    2808.821526
# 236           Myrmeciza hemimelaena   56.020448  57.501636    2350.818912
# 237           Myrmeciza hemimelaena    4.546092   6.180050    2087.500000
# 238           Myrmeciza hemimelaena    7.077805   8.717964    2756.250000
# 239           Myrmeciza hemimelaena   22.337628  23.657521    2670.182788
# 240           Myrmeciza hemimelaena   12.863494  14.375103    2436.684783
# 241           Myrmeciza hemimelaena   46.099127  47.571217    3163.765477
# 242           Myrmeciza hemimelaena   41.821395  43.417674    2925.000000
# 243           Myrmeciza hemimelaena   41.356825  42.937593    2553.495994
# 244           Myrmeciza hemimelaena   46.957153  48.420479    2593.750000
# 245           Myrmeciza hemimelaena   24.146221  25.657830    2103.823744
# 246           Myrmeciza hemimelaena   50.485757  52.076404    2152.002913
# 247           Myrmeciza hemimelaena   13.762556  15.372962    2216.241806
# 248           Myrmeciza hemimelaena   13.515561  15.155607    2408.958485
# 249           Myrmeciza hemimelaena   23.276799  24.788408    2633.794610
# 250           Myrmeciza hemimelaena   33.956858  35.606784    2489.257101
# 251           Myrmeciza hemimelaena   43.224107  44.785114    2569.555717
# 252           Myrmeciza hemimelaena   13.525869  15.094443    2881.250000
# 253           Myrmeciza hemimelaena   32.616320  34.285714    2887.500000
# 254           Myrmeciza hemimelaena   30.286039  31.859251    2975.000000
# 255           Myrmeciza hemimelaena   38.958080  40.580194    2850.000000
# 256           Myrmeciza hemimelaena   14.740655  16.212745    2828.956835
# 257           Myrmeciza hemimelaena   27.120040  28.602009    2749.640288
# 258           Myrmeciza hemimelaena   39.331467  40.833196    2776.079137
# 259           Myrmeciza hemimelaena   53.657171  55.188539    2828.956835
# 260           Myrmeciza hemimelaena   46.415281  47.986168    2636.413043
# 261           Myrmeciza hemimelaena   50.110324  51.473736    2816.168478
# 262           Myrmeciza hemimelaena   54.704429  56.255557    2376.766304
# 263           Myrmeciza hemimelaena   27.604150  29.224436    2576.494565
# 264           Myrmeciza hemimelaena    6.095834   7.785279    2356.793478
# 265           Myrmeciza hemimelaena    2.213074   3.645645    3019.227968
# 266           Myrmeciza hemimelaena   12.626379  14.098469    2842.571012
# 267           Myrmeciza hemimelaena   33.601186  35.063395    2971.048798
# 268           Myrmeciza hemimelaena    6.263533   7.931841    2518.750000
# 269           Myrmeciza hemimelaena   10.396040  12.008487    2194.424460
# 270           Myrmeciza hemimelaena   38.444130  39.886846    2115.107914
# 271           Myrmeciza hemimelaena   24.434876  25.877287    2553.735990
# 272           Myrmeciza hemimelaena   30.374445  31.757986    2375.000000
# 273           Myrmeciza hemimelaena   32.011847  33.450391    2487.500000
# 274           Myrmeciza hemimelaena   42.367442  43.874419    2412.500000
# 275           Myrmeciza hemimelaena    0.582908   2.143916    2300.179856
# 276           Myrmeciza hemimelaena   47.383501  49.082826    2141.546763
# 277           Myrmeciza hemimelaena   43.502347  44.860587    2293.750000
# 278           Myrmeciza hemimelaena   18.754333  20.102930    2468.750000
# 279           Myrmeciza hemimelaena    9.550664  10.936875    2909.375000
# 280           Myrmeciza hemimelaena   22.004730  23.336365    2870.301724
# 281            Percnostola lophotes    5.423719   8.084794    1252.485089
# 282            Percnostola lophotes   49.839228  52.749695    1180.476424
# 283            Percnostola lophotes   28.630162  31.162452    1045.474138
# 284            Percnostola lophotes   17.180754  19.415345     831.250000
# 285            Percnostola lophotes   18.049694  20.439323     843.750000
# 286            Percnostola lophotes   18.064399  20.651264    1071.875000
# 287            Percnostola lophotes   48.374590  50.814843    1381.250000
# 288            Percnostola lophotes    8.094738  10.776179    1125.000000
# 289            Percnostola lophotes   47.218483  49.565217    1429.166667
# 290            Percnostola lophotes   52.348554  55.164635    1159.525862
# 291            Percnostola lophotes   10.445698  12.956158    1444.655172
# 292            Percnostola lophotes    7.487721  10.587593    1211.610044
# 293            Percnostola lophotes    4.238432   7.162852    1541.733430
# 294            Percnostola lophotes   16.420221  19.473078    1461.434814
# 295            Percnostola lophotes    8.698727  11.923621    1637.771739
# 296            Percnostola lophotes    4.328147   7.468175    1537.907609
# 297            Percnostola lophotes   20.495050  23.889675    1458.016304
# 298                Saltator grossus   23.418431  24.971266    1475.568182
# 299                Saltator grossus   17.567570  18.885721    1613.414634
# 300                Saltator grossus   19.799393  21.590402    1410.679134
# 301                Saltator grossus   54.219933  56.094828    1477.945946
# 302                Saltator grossus    2.614309   3.808499    1665.038396
# 303                Saltator grossus   15.271118  16.333456    1661.594437
# 304                Saltator grossus   10.790292  12.395769    1596.724138
# 305                Saltator grossus    4.574401   5.761766    1775.000000
# 306                Saltator grossus   14.327772  15.770363    1462.500000
# 307                Saltator grossus   14.327772  15.770363    1462.500000
# 308        Thamnophilus schistaceus   51.751776  54.398705    1212.500000
# 309        Thamnophilus schistaceus   22.330041  24.612812    1322.491349
# 310        Thamnophilus schistaceus   29.762570  32.207623    1314.013841
# 311        Thamnophilus schistaceus   18.176605  20.399087    1062.500000
# 312        Thamnophilus schistaceus   14.705449  17.190537    1762.500000
# 313        Thamnophilus schistaceus   37.897483  39.997008    1474.401198
# 314        Thamnophilus schistaceus   56.165781  58.619941    1343.750000
# 315        Thamnophilus schistaceus   44.667397  47.073638    1356.250000
# 316        Thamnophilus schistaceus   27.620321  30.294118    1187.500000
# 317        Thamnophilus schistaceus    6.359213   9.202454    1393.750000
# 318        Thamnophilus schistaceus   25.257413  27.931599    1376.531792
#
#      max_frequency                  recording name
# 0      5341.422414          Gb005-2014-09-29_05-10
# 1      5131.250000          Gb005-2014-10-05_06-40
# 2      5412.500000          Gb005-2014-10-06_05-20
# 3      4793.750000          Gb005-2014-10-06_05-50
# 4      5081.250000          Gb005-2014-10-06_06-20
# 5      5350.000000          Gb005-2014-10-08_05-10
# 6      5068.750000          Gb005-2014-10-08_05-40
# 7      4838.309353          Gb005-2014-10-08_06-20
# 8      5123.051712          gb010-2014-10-03_05-30
# 9      5026.693372          gb010-2014-10-03_05-30
# 10     5123.051712          gb010-2014-10-03_05-40
# 11     5372.690217          gb010-2014-10-04_05-20
# 12     5042.753095          gb010-2014-10-06_05-30
# 13     5090.932265          gb010-2014-10-08_05-30
# 14     5058.812819          gb010-2014-10-08_05-40
# 15     6810.259179           250N-2015-01-31_06-10
# 16     7045.730919           250N-2015-01-31_06-10
# 17     6723.845541          gb009-2014-10-06_05-30
# 18     6275.549806          gb009-2014-10-06_05-30
# 19     6418.175938          gb009-2014-10-06_05-30
# 20     3306.250000          Gb004-2014-10-03_05-40
# 21     3162.500000          gb006-2014-10-08_05-20
# 22     3225.000000          gb006-2014-10-08_05-30
# 23     3462.500000          gb009-2014-09-28_05-30
# 24     3661.045910          gb009-2014-09-28_05-40
# 25     3655.481791          gb009-2014-10-04_05-40
# 26     3468.203390          gb009-2014-10-05_05-30
# 27     3579.900744          gb009-2014-10-05_05-50
# 28     3725.613033          gb009-2014-10-06_05-20
# 29     3361.883408          gb009-2014-10-06_05-30
# 30     3367.435622          gb009-2014-10-06_06-00
# 31     6512.393162    Sabana_Seca-2015-08-05_18-50
# 32     6112.500000    Sabana_Seca-2015-08-05_19-10
# 33     6031.250000    Sabana_Seca-2015-08-05_21-10
# 34     6106.250000    Sabana_Seca-2015-08-05_21-20
# 35     6449.572650    Sabana_Seca-2015-08-05_22-40
# 36     6425.000000    Sabana_Seca-2015-08-06_00-00
# 37     6337.500000    Sabana_Seca-2015-08-06_00-00
# 38     6309.824561    Sabana_Seca-2015-08-06_00-30
# 39     5518.750000    Sabana_Seca-2015-08-06_03-30
# 40     6095.262334    Sabana_Seca-2015-08-06_03-50
# 41     6121.162882    Sabana_Seca-2015-08-06_03-50
# 42     5995.161290    Sabana_Seca-2015-08-06_04-50
# 43     5889.883863    Sabana_Seca-2015-08-06_05-20
# 44     6219.230769    Sabana_Seca-2015-08-06_07-50
# 45     4665.700301    Sabana_Seca-2015-08-05_19-10
# 46     4460.256410    Sabana_Seca-2015-08-05_19-20
# 47     4502.136752    Sabana_Seca-2015-08-05_19-20
# 48     4523.076923    Sabana_Seca-2015-08-05_19-20
# 49     4669.658120    Sabana_Seca-2015-08-05_19-30
# 50     4564.957265    Sabana_Seca-2015-08-05_19-30
# 51     4250.854701    Sabana_Seca-2015-08-05_19-30
# 52     4550.817757    Sabana_Seca-2015-08-05_19-40
# 53     4224.532710    Sabana_Seca-2015-08-05_19-40
# 54     4550.817757    Sabana_Seca-2015-08-05_20-00
# 55     4447.780374    Sabana_Seca-2015-08-05_20-00
# 56     4653.855140    Sabana_Seca-2015-08-05_20-10
# 57     4499.299065    Sabana_Seca-2015-08-05_20-10
# 58     4732.115964    Sabana_Seca-2015-08-05_20-50
# 59     4549.472892    Sabana_Seca-2015-08-05_20-50
# 60     4781.250000    Sabana_Seca-2015-08-05_21-10
# 61     4756.250000    Sabana_Seca-2015-08-05_22-10
# 62     4325.000000    Sabana_Seca-2015-08-05_22-10
# 63     4300.000000    Sabana_Seca-2015-08-05_23-30
# 64     4750.000000    Sabana_Seca-2015-08-05_23-30
# 65     4531.250000    Sabana_Seca-2015-08-05_23-30
# 66     4312.500000    Sabana_Seca-2015-08-05_23-30
# 67     4487.500000    Sabana_Seca-2015-08-06_03-30
# 68     4562.500000    Sabana_Seca-2015-08-06_03-30
# 69     4771.210269    Sabana_Seca-2015-08-06_05-20
# 70     2122.913992      lascasa_2-2014-10-18_15-40
# 71     2071.110057      lascasa_2-2014-10-18_16-40
# 72     2008.349146      lascasa_2-2014-10-18_17-10
# 73     1989.627907      lascasa_2-2014-10-18_17-40
# 74     1989.627907      lascasa_2-2014-10-18_18-10
# 75     1893.865031      lascasa_2-2014-10-18_20-00
# 76     2030.921053      lascasa_2-2014-10-18_20-00
# 77     2004.545455      lascasa_2-2014-10-18_20-00
# 78     1925.418660      lascasa_2-2014-10-18_20-20
# 79     1978.169856      lascasa_2-2014-10-18_20-40
# 80     2030.921053      lascasa_2-2014-10-18_20-40
# 81     2004.545455      lascasa_2-2014-10-18_21-00
# 82     1924.667932      lascasa_2-2014-10-18_21-20
# 83     1981.386393      lascasa_2-2014-10-19_05-40
# 84     1861.907021      lascasa_2-2014-10-19_05-40
# 85     1945.588235      lascasa_2-2014-10-19_05-40
# 86     3643.589744    Sabana_Seca-2015-08-05_17-30
# 87     3706.410256    Sabana_Seca-2015-08-05_18-30
# 88     3811.111111    Sabana_Seca-2015-08-05_18-30
# 89     3643.589744    Sabana_Seca-2015-08-05_18-30
# 90     3320.661157    Sabana_Seca-2015-08-06_03-40
# 91     3513.841034    Sabana_Seca-2015-08-06_03-50
# 92     3513.841034    Sabana_Seca-2015-08-06_03-50
# 93     3530.753791    Sabana_Seca-2015-08-06_04-10
# 94     3481.578947    Sabana_Seca-2015-08-06_04-10
# 95     3656.105398    Sabana_Seca-2015-08-06_07-20
# 96     3996.208226    Sabana_Seca-2015-08-06_07-20
# 97     4062.393162    Sabana_Seca-2015-08-06_17-50
# 98     4020.512821    Sabana_Seca-2015-08-06_17-50
# 99     8732.051282    Sabana_Seca-2015-08-05_23-20
# 100    8500.000000    Sabana_Seca-2015-08-06_00-20
# 101    8581.714957    Sabana_Seca-2015-08-06_03-50
# 102    8469.479248    Sabana_Seca-2015-08-06_03-50
# 103    8202.363961    Sabana_Seca-2015-08-06_04-10
# 104     260.492041  Mona_DSG_1014-2012-12-31_22-10
# 105     246.020260  Mona_DSG_1014-2013-01-03_07-25
# 106     267.727931  Mona_DSG_1014-2013-01-18_18-10
# 107     267.727931  Mona_DSG_1014-2013-01-25_22-20
# 108     238.784370  Mona_DSG_1014-2013-01-26_02-35
# 109     253.256151  Mona_DSG_1014-2013-01-26_04-40
# 110     217.076700  Mona_DSG_1014-2013-01-26_05-00
# 111     253.256151  Mona_DSG_1014-2013-01-26_11-00
# 112     260.492041  Mona_DSG_1014-2013-01-26_19-15
# 113     231.548480  Mona_DSG_1014-2013-01-27_07-55
# 114     260.492041  Mona_DSG_1014-2013-01-29_07-20
# 115     231.548480  Mona_DSG_1014-2013-01-29_11-20
# 116     282.199711  Mona_DSG_1014-2013-01-29_19-10
# 117     253.256151  Mona_DSG_1014-2013-01-30_07-45
# 118     260.492041  Mona_DSG_1014-2013-01-30_18-50
# 119     217.076700  Mona_DSG_1014-2013-01-31_08-05
# 120     231.548480  Mona_DSG_1014-2013-01-31_09-35
# 121    2218.158568           100B-2015-01-30_06-10
# 122    2262.500000           100B-2015-01-30_06-40
# 123    2193.750000           500A-2015-02-07_18-10
# 124    2176.863667           500B-2015-02-02_06-00
# 125    2118.750000           750A-2015-02-05_06-40
# 126    2156.250000        default-2015-01-30_12-00
# 127    2181.250000          gb002-2014-10-01_05-40
# 128    2137.500000          gb002-2014-10-01_05-50
# 129    2231.250000          gb002-2014-10-04_05-40
# 130    2175.000000          gb002-2014-10-06_05-40
# 131    2260.077519          Gb004-2014-10-06_06-00
# 132    3734.918478          Gb001-2014-09-27_07-30
# 133    3355.434783          Gb001-2014-10-01_06-50
# 134    3595.108696          Gb001-2014-10-01_06-50
# 135    3768.750000          Gb001-2014-10-02_05-50
# 136    3618.750000          Gb001-2014-10-02_05-50
# 137    3643.454936          Gb001-2014-10-04_05-30
# 138    3516.366906          Gb001-2014-10-06_05-20
# 139    3516.366906          Gb001-2014-10-06_05-20
# 140    3131.250000          gb002-2014-10-01_05-40
# 141    3168.750000          gb002-2014-10-01_06-40
# 142    3243.750000          gb002-2014-10-02_05-40
# 143    3677.676621          gb002-2014-10-02_05-50
# 144    3340.422433          gb002-2014-10-02_05-50
# 145    3677.676621          gb002-2014-10-02_05-50
# 146    3243.750000          gb002-2014-10-03_06-00
# 147    3393.810931          gb002-2014-10-03_06-00
# 148    3381.250000          gb002-2014-10-04_05-40
# 149    3150.000000          gb002-2014-10-06_05-40
# 150    3187.500000          gb002-2014-10-06_05-50
# 151    3326.508621          Gb005-2014-09-28_05-20
# 152    3326.508621          Gb005-2014-09-28_05-20
# 153    3266.666667          Gb005-2014-10-08_05-40
# 154    3496.354167          Gb005-2014-10-08_05-40
# 155    3274.407583          gb009-2014-10-05_05-50
# 156   12187.017995    Sabana_Seca-2015-08-05_21-40
# 157   12357.069409    Sabana_Seca-2015-08-05_22-10
# 158   11903.598972    Sabana_Seca-2015-08-05_22-40
# 159   12243.701800    Sabana_Seca-2015-08-05_22-50
# 160   12498.778920    Sabana_Seca-2015-08-05_23-00
# 161   13235.668380    Sabana_Seca-2015-08-06_00-30
# 162   12413.753213    Sabana_Seca-2015-08-06_00-40
# 163   12527.120823    Sabana_Seca-2015-08-06_04-20
# 164   10713.239075    Sabana_Seca-2015-08-06_04-50
# 165   11732.508251    Sabana_Seca-2015-08-06_04-50
# 166    1525.000000          1000B-2015-02-09_05-50
# 167    1468.002717           250A-2015-01-30_06-40
# 168    1526.883910           250W-2015-02-09_05-50
# 169    1618.750000           500B-2015-02-05_06-40
# 170    1612.500000           500B-2015-02-05_06-50
# 171    1481.250000           750B-2015-02-02_06-50
# 172    1561.782477           750B-2015-02-06_08-50
# 173    1555.361596           750B-2015-02-06_10-40
# 174    1537.500000          gb002-2014-10-08_06-20
# 175    1643.750000          Gb004-2014-10-07_05-50
# 176    1643.750000          Gb004-2014-10-07_05-50
# 177    1500.000000          gb010-1970-01-06_05-40
# 178    1487.500000          gb010-1970-01-06_05-40
# 179    1512.500000          gb010-1970-01-06_05-50
# 180    1072.101986           250W-2015-02-09_00-00
# 181    1072.101986           250W-2015-02-09_00-00
# 182    1074.690038           250W-2015-02-09_00-10
# 183    1031.062124           250W-2015-02-09_00-20
# 184    1075.250501           250W-2015-02-09_00-20
# 185    1112.232030           250W-2015-02-09_00-30
# 186     800.000000         ep200b-2015-04-16_05-40
# 187     800.000000         ep200b-2015-04-16_05-40
# 188     600.000000      toro_100a-2015-03-30_19-50
# 189     600.000000      toro_100a-2015-03-30_19-50
# 190     651.649485      toro_200a-2015-03-28_02-20
# 191     612.500000      toro_200a-2015-03-28_21-20
# 192     650.000000      toro_200a-2015-03-29_22-20
# 193     706.250000      toro_200a-2015-03-30_04-10
# 194     674.438202      toro_200a-2015-03-31_01-00
# 195     701.966292      toro_200a-2015-03-31_01-00
# 196     637.500000      toro_200a-2015-04-01_21-00
# 197     618.750000      toro_200a-2015-04-01_21-00
# 198     668.750000      toro_200a-2015-04-07_01-20
# 199     601.637108      toro_200a-2015-04-07_01-20
# 200     656.250000      toro_200b-2015-03-29_23-40
# 201    3083.620690          1000A-2015-02-11_15-20
# 202    3080.792997          1000A-2015-02-12_15-10
# 203    3037.500000           500A-2015-02-12_13-20
# 204    2968.750000        default-2015-01-30_06-00
# 205    3187.500000          gb002-2014-10-02_05-40
# 206    3278.513146          gb002-2014-10-05_06-20
# 207    3043.750000          gb003-2014-09-27_06-20
# 208    3271.612415          gb003-2014-10-01_17-30
# 209    3270.574163          gb003-2014-10-03_07-20
# 210    3215.907692          gb003-2014-10-05_06-10
# 211    3075.000000          gb010-1970-01-05_07-40
# 212    3036.478172          gb010-2014-10-04_06-40
# 213    3487.089116          1000B-2015-02-08_06-10
# 214    3237.500000           500B-2015-02-02_06-00
# 215    3484.959942          Gb001-2014-09-28_07-50
# 216    3162.500000          Gb001-2014-10-01_06-20
# 217    3543.750000          Gb001-2014-10-02_05-50
# 218    3400.000000          gb002-2014-10-04_06-20
# 219    3346.281407          gb002-2014-10-05_05-50
# 220    3231.250000          gb002-2014-10-06_05-30
# 221    3143.750000          gb002-2014-10-06_05-40
# 222    3362.703863          gb002-2014-10-06_05-50
# 223    3463.489209          gb006-2014-09-28_08-00
# 224    3605.331754          gb009-2014-10-05_05-50
# 225    3195.884924          gb010-2014-10-03_05-40
# 226    3163.765477          gb010-2014-10-06_05-30
# 227    3244.064093          gb010-2014-10-06_05-30
# 228    3131.646031          gb010-2014-10-06_05-40
# 229    3035.287691          gb010-2014-10-06_05-40
# 230    3099.526584          gb010-2014-10-08_05-40
# 231    3115.586307          gb010-2014-10-08_06-10
# 232    3115.586307          gb010-2014-10-08_07-20
# 233    3115.586307          gb010-2014-10-08_07-20
# 234    3099.526584          gb010-2014-10-08_07-20
# 235    3845.231608          1000B-2015-02-08_06-10
# 236    3890.775649          1000B-2015-02-09_05-50
# 237    3875.000000           100B-2015-02-01_05-50
# 238    4056.250000           500A-2015-02-12_08-30
# 239    3854.131759           750A-2015-02-11_07-00
# 240    3974.592391          Gb001-2014-09-28_06-10
# 241    4304.005827          Gb001-2014-09-28_07-50
# 242    4256.250000          Gb001-2014-10-01_06-00
# 243    4030.990532          Gb001-2014-10-01_10-10
# 244    4256.250000          Gb001-2014-10-02_05-50
# 245    4207.647487          Gb001-2014-10-03_06-50
# 246    4304.005827          Gb001-2014-10-03_06-50
# 247    4175.528041          Gb001-2014-10-03_06-50
# 248    4207.647487          Gb001-2014-10-03_07-00
# 249    4271.886380          Gb001-2014-10-03_07-00
# 250    4304.005827          Gb001-2014-10-03_07-00
# 251    4175.528041          Gb001-2014-10-03_07-00
# 252    4156.250000          Gb001-2014-10-04_05-30
# 253    4262.500000          Gb001-2014-10-04_06-50
# 254    4143.750000          Gb001-2014-10-05_05-20
# 255    4106.250000          Gb001-2014-10-05_05-30
# 256    4256.654676          Gb001-2014-10-06_05-30
# 257    4150.899281          Gb001-2014-10-06_05-30
# 258    4150.899281          Gb001-2014-10-06_05-30
# 259    4177.338129          Gb001-2014-10-06_05-30
# 260    4154.347826          Gb001-2014-10-06_05-50
# 261    3954.619565          Gb001-2014-10-06_05-50
# 262    4214.266304          Gb001-2014-10-06_05-50
# 263    4294.157609          Gb001-2014-10-06_05-50
# 264    4134.375000          Gb001-2014-10-06_05-50
# 265    4223.707210          Gb001-2014-10-06_06-00
# 266    4223.707210          Gb001-2014-10-06_06-00
# 267    4191.587764          Gb001-2014-10-06_06-00
# 268    4343.750000          Gb001-2014-10-08_06-40
# 269    3965.827338          Gb004-2014-10-03_05-50
# 270    3860.071942          Gb004-2014-10-03_05-50
# 271    4228.767123          Gb004-2014-10-03_05-50
# 272    3850.000000          Gb004-2014-10-05_05-40
# 273    4000.000000          Gb004-2014-10-05_05-50
# 274    3925.000000          Gb004-2014-10-05_05-50
# 275    4335.971223          gb007-2014-09-27_06-50
# 276    4388.848921          gb007-2014-09-27_06-50
# 277    4018.750000          gb007-2014-10-05_06-10
# 278    4050.000000          gb007-2014-10-05_06-10
# 279    4210.937500          Gb008-2014-10-02_07-50
# 280    4105.862069          Gb008-2014-10-02_07-50
# 281    2517.495030          1000A-2015-02-01_05-50
# 282    2664.194499          1000A-2015-02-03_06-10
# 283    2395.086207          Gb005-2014-09-28_07-50
# 284    2412.500000          Gb005-2014-10-01_08-20
# 285    2512.500000          Gb005-2014-10-05_06-50
# 286    2577.604167          Gb005-2014-10-06_05-20
# 287    2481.250000          Gb005-2014-10-06_06-00
# 288    2787.500000          Gb005-2014-10-08_05-20
# 289    2552.083333          Gb005-2014-10-08_05-40
# 290    2414.094828          Gb005-2014-10-08_06-20
# 291    2395.086207          Gb005-2014-10-08_06-20
# 292    2507.902511          gb009-2014-10-05_06-30
# 293    2922.869629          gb010-2014-10-04_06-50
# 294    3067.407138          gb010-2014-10-04_06-50
# 295    2776.222826          gb010-2014-10-04_07-10
# 296    2876.086957          gb010-2014-10-05_07-10
# 297    2916.032609          gb010-2014-10-05_08-20
# 298    2951.136364           175B-2015-02-09_08-10
# 299    2791.463415          Gb001-2014-09-29_05-40
# 300    2821.358268          Gb001-2014-09-30_05-40
# 301    2789.027027          Gb001-2014-09-30_05-40
# 302    2624.552048          Gb005-2014-09-27_06-00
# 303    2717.027814          Gb005-2014-09-27_06-20
# 304    2870.301724          Gb005-2014-09-27_06-50
# 305    2875.000000          gb006-2014-09-27_05-50
# 306    2725.000000          gb007-2014-10-03_06-50
# 307    2725.000000          gb007-2014-10-03_06-50
# 308    1937.500000          1000A-2015-02-06_06-30
# 309    2000.692042           250N-2015-02-05_06-20
# 310    2009.169550           250N-2015-02-05_06-20
# 311    2325.000000          Gb001-2014-10-07_05-30
# 312    2293.750000          Gb001-2014-10-07_05-30
# 313    2156.586826          Gb001-2014-10-07_05-40
# 314    2031.250000          gb006-2014-09-28_06-20
# 315    2000.000000          gb006-2014-09-28_07-00
# 316    2043.750000          gb006-2014-09-28_07-00
# 317    2156.250000          gb006-2014-10-03_06-30
# 318    2090.289017          gb006-2014-10-03_06-40

# %% [markdown]
# ### Exporting Data

# %% [markdown]
# We need to export the different species recordings in pickle format, because it is easier to manipulate later on. But also want to export the dictionary in a .yaml file for later use. Also, we want a compressed version of this data in case it becomes necessary.

# %%
# save our species data dictionary as a .yaml file for later use
workbook = '../dataset/corrected_validationsAndROIs.xlsx'
data = speciesData(workbook)
dataToYAML(data, 'dataset.yaml')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-26-b335e16b25be> in <module>()
#       2 workbook = '../dataset/corrected_validationsAndROIs.xlsx'
#       3 data = speciesData(workbook)
# ----> 4 dataToYAML(data, 'dataset.yaml')
#
# <ipython-input-15-be7cf1f3f3dd> in dataToYAML(data, name)
#      34     # need to check if file exists then delete it
#      35     path = '../dataset/' + name
# ---> 36     dataset = open(path, 'w+')
#      37     dump = yaml.dump(data, dataset, default_flow_style=False)
#      38     dataset.close()
#
# PermissionError: [Errno 13] Permission denied: '../dataset/dataset.yaml'

# %%
def getRawSpecDataset(dataset, path='../dataset'):
    
    # make directory to store our spec dataset
    dataset_path = path + '/spectrogram_roi_dataset'
    if not os.path.exists(dataset_path):
        os.makedirs(dataset_path)
    else:
        shutil.rmtree(dataset_path)
        os.makedirs(dataset_path)
    species = dataset.keys()
    
    # image data to be pickled 
    # should be fixed: a list of dictionaries consume more memory 
    specs = []
    
    for s in species:
        s_dir = dataset_path + '/' + s
        s_spec = []
        os.makedirs(s_dir) # make a directory per species
        
        # load species ROI data
        min_freqs = dataset[s]['min_frequency']
        max_freqs = dataset[s]['max_frequency']
        starts = dataset[s]['start_time']
        ends = dataset[s]['end_time']
        recs = dataset[s]['recording name']
        
        for i in range(0, len(recs)):
            rec = '../dataset/recordings/' + recs[i] # path to ith recording file where s is present
            spectrum, freqs, times = specInfo(rec) # get entire spectrogram data from rec
            
            # get ROI info in rec
            t_0 = starts[i] 
            t_n = ends[i]
            f_0 = min_freqs[i]
            f_n = max_freqs[i]
            
            # find closest times and freqs that match ROI info
            t_start, t_end = getBounds(times, t_0, t_n)
            f_start, f_end = getBounds(freqs, f_0, f_n)
            
            # get modified spectrum, freqs, and times
            spectrumMod = specMod(spectrum, freqs, times, f_start, f_end, t_start, t_end)
            freqMod = freqs[f_start:f_end]
            timeMod = times[t_start:t_end]
            filename = s_dir + '/' + s + '_spec_' + str(i+1) + '.png'
            
            # plot the spectrogram of ROI and save the image 
            f = plotModSpecSimple(spectrumMod, freqMod, timeMod, filename)
            s_spec.append(f) # append image to list of ROI spectrograms per species
            pylab.close
        
        # add dictionary with key <species_name> and value <list_of_spectrogram_figures>
        # here each element in the array is a dictionary with one key value pair
        # we can store that in a single dictionary and avoid dictionaries' main con: memory usage
        specs.append({s:s_spec}) 
    
    return specs

# %%
yamlData = open('../dataset/dataset.yaml', 'r')
dataset = yaml.load(yamlData)
yamlData.close()
data = getRawSpecDataset(dataset)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   """
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   """
# /opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
# Pickles the data
def serializeDataset(obj, path='../dataset'):
    pickle_path = path + '/pickle_data'
    # create pickle directory if exists, else overwrite it
    if not os.path.exists(pickle_path):
        os.makedirs(pickle_path)
    else:
        shutil.rmtree(pickle_path)
        os.makedirs(pickle_path)
    for s in obj:
        species = list(s.keys())[0]
        data = s[species]
        picklename = pickle_path + '/' + species + '.pickle'
        with open(picklename, 'wb+') as pn:
            cpl.dump(data, pn)

# %%
serializeDataset(data)

# %%
# Compresses the data 
def archiveAndCompress(path):
    directory = path.split('/')[0:-1]
    directory = '/'.join(directory)
    archive_name = directory + '/' + path.split('/')[-1] + '.tar.bz2'
    with tarfile.open(archive_name, 'w:bz2') as archive:
        folder = os.listdir(path)
        for f in folder:
            f = path + '/' + f
            archive.add(f, arcname=os.path.basename(f))

# %%
archiveAndCompress('../dataset/spectrogram_roi_dataset')
archiveAndCompress('../dataset/pickle_data')
